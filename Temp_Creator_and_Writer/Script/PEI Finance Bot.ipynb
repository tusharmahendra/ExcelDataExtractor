# %% [markdown]
# <h2>Hello!</h2>
#
# <p>I am a PEI Finance Bot. I am designed to manipulate big data of all stores. I can uniquly identify data for each store. I use my super ability to write each store's PEI data into their excel workbook.
#
# Don't worry if you're a new store and your file doesn't exist or you deleted your file by mistake! I will automatically generate one for you.
#
# <i>author: Tushar Mahendra<br>
# date: 2022-09-04</i>
#
# </p>

# %%
import pandas as pd
import openpyxl
import datetime
import os
import shutil
import win32com.client as win32

# %%
csv_file = 'C:\\Users\\620110\\OneDrive - Save-On-Foods\\Documents\\Python Project\\Temp_Creator_and_Writer\\Main_Files\\BigData.csv'
master_temp = 'C:\\Users\\620110\\OneDrive - Save-On-Foods\\Documents\\Python Project\\Temp_Creator_and_Writer\\Main_Files\\MasterTemplate.xlsx'

# %%
# %%time

x = datetime.date.today()

prd = "Period 1"
i = 0

if (x.month == 1):
    prd = "Period 1"
    i = 0
    print("Current Month: January - " + prd)

elif (x.month == 2):
    prd = "Period 2"
    i = 1
    print("Current Month: February - " + prd)

elif (x.month == 3):
    prd = "Period 3"
    i = 2
    print("Current Month: March - " + prd)

elif (x.month == 4):
    prd = "Period 4"
    i = 3
    print("Current Month: April - " + prd)

elif (x.month == 5):
    prd = "Period 5"
    i = 4
    print("Current Month: May - " + prd)

elif (x.month == 6):
    prd = "Period 6"
    i = 5
    print("Current Month: June - " + prd)

elif (x.month == 7):
    prd = "Period 7"
    i = 6
    print("Current Month: July - " + prd)

elif (x.month == 8):
    prd = "Period 8"
    i = 7
    print("Current Month: August - " + prd)

elif (x.month == 9):
    prd = "Period 9"
    i = 8
    print("Current Month: September - " + prd)

elif (x.month == 10):
    prd = "Period 10"
    i = 9
    print("Current Month: October - " + prd)
    
elif (x.month == 11):
    prd = "Period 11"
    i = 10
    print("Current Month: November - " + prd)

elif (x.month == 12):
    prd = "Period 12"
    i = 11
    print("Current Month: December - " + prd)
# Out:
# Current Month: July - Period 7
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
#Checks and makes directory for every year
dkr_path = 'C:\\Users\\620110\\OneDrive - Save-On-Foods\\Documents\\Python Project\\Temp_Creator_and_Writer\\Test_Files\\' + str(x.year)
if (os.path.exists(dkr_path)):
    print("Directory exists.")
    print("Files will be generated in:") 
    print(dkr_path)
    
else:
    (os.mkdir(dkr_path)) #Can assign implicit permissions on this directory
    print("Directory does not exist.")
    print("Creating directory: ")
    print(dkr_path)
# Out:
# Directory exists.
# Files will be generated in:
# C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Test_Files\2023

# %%
# %%time


df = pd.read_csv(csv_file) #creates a pandas dataframe to read the file

df['Department']= pd.Categorical(df['Department'],
categories=["Tobacco-1008",
"Coffee Shop-2900",
"Wine-3200",
"Meats-2000",
"Seafood-2600",
"Deli-2500",
"Restaurant-2700",
"Produce-3000",
"Floral-3100",
"Bakery-1500"])

df = df.sort_values('Department')
new_df = pd.DataFrame()
split_values = df['User'].unique() #selects all the unique values from the chosen column.
#print(split_values)

#Iterates each value from split_values and creates a dataframe of unique column.
for value in split_values:
    store_df = df[df['User'] == value]
    new_df = store_df[['Unpaid Liabilities', 'Goods In Transit']]
    #print(new_df)
    #print(value)
    
    file_path = dkr_path + '\\' + str(value) + '.xlsx'
    #print(file_path)
    
    if(os.path.exists(file_path)):
        print("file exists: " + str(value))
        
    else:
        #Creates template for all the stores
        print("File does not exist. Creating new file: " + str(value))
        wb_temp = openpyxl.load_workbook(master_temp)
        wb_temp.save(file_path)
    
    #To edit the column in a WB 
    wb = openpyxl.load_workbook(file_path)
    ws = wb.worksheets[i]
    ws['B2']=value.replace("SM","")
    wb.save(file_path)
        
    #Writing the dfs to the excel files
    writer = pd.ExcelWriter(
        file_path, 
        if_sheet_exists='overlay', 
        engine='openpyxl', 
        mode='a')
    
    new_df.to_excel(writer, sheet_name=prd, startrow=4, startcol=1, index=None, header=False)
    writer.close()
# Out:
# file exists: 7638SM
# file exists: 4425SM
# file exists: 2248SM
# file exists: 968SM
# file exists: 932SM
# file exists: 967SM
# file exists: 2221SM
# file exists: 6635SM
# file exists: 6603SM
# file exists: 966SM
# file exists: 6675SM
# file exists: 931SM
# file exists: 2247SM
# file exists: 2222SM
# file exists: 6636SM
# file exists: 965SM
# file exists: 934SM
# file exists: 5505SM
# file exists: 964SM
# file exists: 2223SM
# file exists: 2246SM
# file exists: 6602SM
# file exists: 6673SM
# file exists: 933SM
# file exists: 963SM
# file exists: 6634SM
# file exists: 969SM
# file exists: 6630SM
# file exists: 975SM
# file exists: 2215SM
# file exists: 4420SM
# file exists: 2250SM
# file exists: 928SM
# file exists: 973SM
# file exists: 6606SM
# file exists: 2217SM
# file exists: 6632SM
# file exists: 2220SM
# file exists: 972SM
# file exists: 944SM
# file exists: 6679SM
# file exists: 971SM
# file exists: 6633SM
# file exists: 2249SM
# file exists: 2219SM
# file exists: 930SM
# file exists: 970SM
# file exists: 6678SM
# file exists: 6604SM
# file exists: 929SM
# file exists: 6682SM
# file exists: 6637SM
# file exists: 962SM
# file exists: 2243SM
# file exists: 952SM
# file exists: 940SM
# file exists: 2229SM
# file exists: 5515SM
# file exists: 941SM
# file exists: 6661SM
# file exists: 951SM
# file exists: 5533SM
# file exists: 948SM
# file exists: 6667SM
# file exists: 2235SM
# file exists: 942SM
# file exists: 6662SM
# file exists: 947SM
# file exists: 6664SM
# file exists: 999SM
# file exists: 2237SM
# file exists: 943SM
# file exists: 946SM
# file exists: 2241SM
# file exists: 5530SM
# file exists: 2242SM
# file exists: 935SM
# file exists: 6650SM
# file exists: 5540SM
# file exists: 2224SM
# file exists: 6643SM
# file exists: 936SM
# file exists: 961SM
# file exists: 6672SM
# file exists: 2245SM
# file exists: 957SM
# file exists: 2225SM
# file exists: 5545SM
# file exists: 937SM
# file exists: 953SM
# file exists: 5508SM
# file exists: 956SM
# file exists: 938SM
# file exists: 2226SM
# file exists: 6647SM
# file exists: 955SM
# file exists: 2244SM
# file exists: 6670SM
# file exists: 954SM
# file exists: 939SM
# file exists: 2228SM
# file exists: 6645SM
# file exists: 923SM
# file exists: 6663SM
# file exists: 995SM
# file exists: 915SM
# file exists: 985SM
# file exists: 993SM
# file exists: 2274SM
# file exists: 4410SM
# file exists: 2210SM
# file exists: 904SM
# file exists: 916SM
# file exists: 2206SM
# file exists: 6609SM
# file exists: 984SM
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:40, in <module>
#
# File ~\Anaconda3\lib\site-packages\openpyxl\reader\excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
#    (...)
#     313
#     314 """
#     315 reader = ExcelReader(filename, read_only, keep_vba,
#     316                     data_only, keep_links)
# --> 317 reader.read()
#     318 return reader.wb
#
# File ~\Anaconda3\lib\site-packages\openpyxl\reader\excel.py:276, in ExcelReader.read(self)
#     275 def read(self):
# --> 276     self.read_manifest()
#     277     self.read_strings()
#     278     self.read_workbook()
#
# File ~\Anaconda3\lib\site-packages\openpyxl\reader\excel.py:134, in ExcelReader.read_manifest(self)
#     133 def read_manifest(self):
# --> 134     src = self.archive.read(ARC_CONTENT_TYPES)
#     135     root = fromstring(src)
#     136     self.package = Manifest.from_tree(root)
#
# File ~\Anaconda3\lib\zipfile.py:1472, in ZipFile.read(self, name, pwd)
#    1470 def read(self, name, pwd=None):
#    1471     """Return file bytes for name."""
# -> 1472     with self.open(name, "r", pwd) as fp:
#    1473         return fp.read()
#
# File ~\Anaconda3\lib\zipfile.py:1511, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1508     zinfo._compresslevel = self.compresslevel
#    1509 else:
#    1510     # Get info object for name
# -> 1511     zinfo = self.getinfo(name)
#    1513 if mode == 'w':
#    1514     return self._open_to_write(zinfo, force_zip64=force_zip64)
#
# File ~\Anaconda3\lib\zipfile.py:1438, in ZipFile.getinfo(self, name)
#    1436 info = self.NameToInfo.get(name)
#    1437 if info is None:
# -> 1438     raise KeyError(
#    1439         'There is no item named %r in the archive' % name)
#    1441 return info
#
# KeyError: "There is no item named '[Content_Types].xml' in the archive"

# %%
# %%time
ban_dir = 'C:\\Users\\620110\\OneDrive - Save-On-Foods\\Documents\\Python Project\\Temp_Creator_and_Writer\\Banners\\'

for filename in os.listdir(dkr_path):
    f = os.path.join(dkr_path, filename)
    #checking if it is a file.
    if os.path.isfile(f):
        edit_filename = filename
        edit_filename = edit_filename.replace('SM.xlsx','')
        zero_filled_number = edit_filename.zfill(4)
        
        #Creates location id to compare store's excel file with store's directory.
        location_id = ("Store " + zero_filled_number)
        l = os.path.join(ban_dir,location_id)
        
        #Creates a directory if path does not exist.
        if not os.path.exists(l):
            os.mkdir(l)
            print("Missing directory for "+ l +". Creating now.")

        #Compare and transfer file to its store's folder.
        for folder in os.listdir(ban_dir):
            d = os.path.join(ban_dir, folder)
            if(location_id==folder):
                shutil.copy(f,d)
                print("File copied to: " + d)
# Out:
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2202
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2206
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2207
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2208
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2209
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2210
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2211
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2212
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2213
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2214
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2215
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2217
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2219
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2220
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2221
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2222
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2223
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2224
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2225
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2226
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2228
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2229
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2235
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2237
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2241
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2242
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2243
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2244
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2245
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2246
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2247
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2248
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2249
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2250
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2252
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2260
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2261
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2263
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2267
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2274
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2281
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 2289
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 4405
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 4410
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 4415
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 4420
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 4425
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 5505
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 5508
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 5515
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 5530
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 5533
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 5540
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 5545
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6602
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6603
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6604
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6606
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6607
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6608
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6609
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6612
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6613
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6614
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6615
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6616
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6617
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6618
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6619
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6620
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6622
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6623
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6628
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6629
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6630
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6632
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6633
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6634
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6635
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6636
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6637
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6643
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6645
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6647
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6650
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6661
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6662
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6663
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6664
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6667
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6670
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6672
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6673
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6675
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6678
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6679
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6682
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6686
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 6690
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 7614
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 7618
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 7623
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 7630
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 7638
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0902
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0903
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0904
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0907
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0909
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0910
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0915
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0916
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0918
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0919
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0921
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0922
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0923
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0928
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0929
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0930
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0931
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0932
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0933
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0934
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0935
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0936
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0937
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0938
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0939
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0940
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0941
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0942
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0943
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0944
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0946
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0947
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0948
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0951
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0952
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0953
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0954
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0955
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0956
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0957
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0961
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0962
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0963
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0964
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0965
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0966
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0967
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0968
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0969
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0970
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0971
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0972
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0973
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0975
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0977
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0978
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0979
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0980
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0981
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0982
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0983
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0984
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0985
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0987
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0988
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0990
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0991
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0992
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0993
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0995
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0996
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0998
# File copied to: C:\Users\620110\OneDrive - Save-On-Foods\Documents\Python Project\Temp_Creator_and_Writer\Banners\Store 0999
# CPU times: total: 1.16 s
# Wall time: 1.21 s

# %%
#Creates & send email to *Active Directory Email Group*
outlook = win32.Dispatch("outlook.application")

mail = outlook.CreateItem(0)
mail.To = "sofmgrs@saveonfoods.com"
# mail.CC = "cc_email_address"
mail.Subject = f"PEI Report Uploaded for All Stores"

mail.HTMLBody = f"""Hello,<br>
<br>
Your PEI Report has been uploaded.<br>
<br>    
Please contact IT Help Desk to report an issue.<br>
<br>
Thank you.<br>
IT Support Team
""" 
# attach_path = "C:\\Users\\620110\\OneDrive - Save-On-Foods\\Documents\\Python Project\\Temp_Creator_and_Writer\\Test_Files\\" + str(current_year) + "\\" + row['User'] + ".xlsx"
# mail.Attachments.Add(Source=attach_path) 

mail.Display()

# mail.Send()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 writer.close()
#
# File ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py:1205, in ExcelWriter.close(self)
#    1203 def close(self) -> None:
#    1204     """synonym for save, to make it more file-like"""
# -> 1205     self.save()
#    1206     self.handles.close()
#
# File ~\Anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:81, in OpenpyxlWriter.save(self)
#      77 def save(self):
#      78     """
#      79     Save workbook to disk.
#      80     """
# ---> 81     self.book.save(self.handles.handle)
#      82     if "r+" in self.mode and not isinstance(self.handles.handle, mmap.mmap):
#      83         # truncate file to the written content
#      84         self.handles.handle.truncate()
#
# File ~\Anaconda3\lib\site-packages\openpyxl\workbook\workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# --> 407 save_workbook(self, filename)
#
# File ~\Anaconda3\lib\site-packages\openpyxl\writer\excel.py:291, in save_workbook(workbook, filename)
#     279 def save_workbook(workbook, filename):
#     280     """Save the given workbook on the filesystem under the name filename.
#     281
#     282     :param workbook: the workbook to save
#    (...)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292     writer = ExcelWriter(workbook, archive)
#     293     writer.save()
#
# File ~\Anaconda3\lib\zipfile.py:1272, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1270 self._didModify = True
#    1271 try:
# -> 1272     self.start_dir = self.fp.tell()
#    1273 except (AttributeError, OSError):
#    1274     self.fp = _Tellable(self.fp)
#
# ValueError: I/O operation on closed file
